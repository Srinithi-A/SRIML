# %% [markdown]
# <a href="https://colab.research.google.com/github/Srinithi-A/SRIML/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Srinithi-A/SRIML/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# I chose the SEO Content Optimization lane.
# I selected this lane because the starter dataset contains information about search impressions, click-through rate (CTR), average search position, and content characteristics. These variables can help identify pages that may benefit from optimization.
# This project focuses on supporting decision-making rather than proving why Google ranks pages in a certain way.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# Research Question:
# Which webpages are most likely to have a low click-through rate (CTR) despite receiving search impressions, and therefore should be prioritized for optimization?
# Decision:
# The project helps decide which webpages should be optimized first.
#
# 1. Who takes the action?
# An SEO specialist or website content manager can update page titles, meta descriptions, headings, or page content to improve search performance.
#
# 2. Cost of a wrong recommendation:
# If the model recommends optimizing the wrong pages, time and resources may be spent on pages with little potential for improvement. If important pages are missed, the website may lose opportunities to gain additional traffic and user engagement.
#
# 3. Why use data or machine learning?
# Instead of manually reviewing hundreds or thousands of webpages, machine learning can identify patterns in historical search performance and provide decision-support by highlighting pages that are more likely to benefit from optimization.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import os

for root, dirs, files in os.walk("../../data"):
    for file in files:
        print(os.path.join(root, file))

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# ## Careful Words
#
# This project uses the available data to identify observed patterns and provide decision-support for webpage optimization. Any relationships found between variables, such as average position and click-through rate, are observations within this dataset.
# The project does **not** prove how Google's ranking algorithm works, establish cause-and-effect relationships, or guarantee that optimizing a recommended page will improve rankings or traffic. The results should be interpreted as evidence that can help guide decisions rather than definitive proof.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
