# %% [markdown]
# <a href="https://colab.research.google.com/github/Srinithi-A/SRIML/blob/main/work/notebooks/w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Srinithi-A/SRIML/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# I am continuing with the SEO Content Optimization lane.
#
# The ML task is **classification**. The goal is to classify webpages into groups such as "needs optimization" or "does not need optimization" based on search performance and page characteristics.
# This framing supports decision-making by helping identify which pages should be prioritized for improvement.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# Since there is no direct column that says whether a page needs optimization, I will use a proxy target.
#
# One possible target is whether a webpage has a low click-through rate (CTR) despite receiving search impressions.
#
# For example:
# - 1 = Needs optimization
# - 0 = Does not currently need optimization
#
# This target is only a proxy based on observed data and is not a direct measure of page quality.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# The success of the model can be measured using classification metrics such as Precision, Recall, and F1 Score.
#
# Precision is particularly important because recommending unnecessary pages for optimization wastes time and resources.
#
# The model should also remain interpretable so that SEO specialists can understand why recommendations are made.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# The unit of analysis is **one webpage**.
#
# Each row in the dataset represents a single webpage, while the columns describe its search performance and content characteristics, such as impressions, click-through rate (CTR), average search position, and engagement-related features. The model makes one prediction for each webpage.

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# A fixed rule, such as "optimize every page with CTR below 5%", ignores many other factors like search position, impressions, content age, and engagement.
#
# Machine learning can consider several features simultaneously and identify patterns that are difficult to capture using simple threshold rules.
#
# The goal is not to replace human decision-making but to provide decision-support by prioritizing pages that are more likely to benefit from optimization.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
